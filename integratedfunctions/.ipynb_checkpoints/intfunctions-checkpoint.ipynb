# %%
import numpy as np
import matplotlib.pyplot as plt
import os.path
from tabulate import tabulate #to export in table format

# %%
X_ = np.linspace(-10, 50, 60 + 1)

# %%
#filter lists
M0_g = []
M1_g = []
M2_g = []

#reading the file
file = open("cspg.dat")
lines = file.readlines()
file.close()

for line in lines:
    if line.startswith('#'): continue
    co=line.rstrip().replace('INDEF','Nan').split()

    M0_g.append(co[0])
    M1_g.append(co[1])
    M2_g.append(co[2])

#converting to float
M0_g = np.array(M0_g, dtype=float)
M1_g = np.array(M1_g, dtype=float)
M2_g = np.array(M2_g, dtype=float)

# %%
#filter lists
M0_b = []
M1_b = []
M2_b = []

#reading the file
file = open("cspb.dat")
lines = file.readlines()
file.close()

for line in lines:
    if line.startswith('#'): continue
    co=line.rstrip().replace('INDEF','Nan').split()

    M0_b.append(co[0])
    M1_b.append(co[1])
    M2_b.append(co[2])

#converting to float
M0_b = np.array(M0_b, dtype=float)
M1_b = np.array(M1_b, dtype=float)
M2_b = np.array(M2_b, dtype=float)

# %%
#filter lists
M0_r = []
M1_r = []
M2_r = []

#reading the file
file = open("cspr.dat")
lines = file.readlines()
file.close()

for line in lines:
    if line.startswith('#'): continue
    co=line.rstrip().replace('INDEF','Nan').split()

    M0_r.append(co[0])
    M1_r.append(co[1])
    M2_r.append(co[2])

#converting to float
M0_r = np.array(M0_r, dtype=float)
M1_r = np.array(M1_r, dtype=float)
M2_r = np.array(M2_r, dtype=float)

# %%
#filter lists
M0_i = []
M1_i = []
M2_i = []

#reading the file
file = open("cspi.dat")
lines = file.readlines()
file.close()

for line in lines:
    if line.startswith('#'): continue
    co=line.rstrip().replace('INDEF','Nan').split()

    M0_i.append(co[0])
    M1_i.append(co[1])
    M2_i.append(co[2])

#converting to float
M0_i = np.array(M0_i, dtype=float)
M1_i = np.array(M1_i, dtype=float)
M2_i = np.array(M2_i, dtype=float)

# %%
#filter lists
M0_i_0 = []
M1_i_0 = []
M2_i_0 = []

#reading the file
file = open("cspi2.dat")
lines = file.readlines()
file.close()

for line in lines:
    if line.startswith('#'): continue
    co=line.rstrip().replace('INDEF','Nan').split()

    M0_i_0.append(co[0])
    M1_i_0.append(co[1])
    M2_i_0.append(co[2])

#converting to float
M0_i_0 = np.array(M0_i_0, dtype=float)
M1_i_0 = np.array(M1_i_0, dtype=float)
M2_i_0 = np.array(M2_i_0, dtype=float)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-032379e96332> in <module>
#       5
#       6 #reading the file
# ----> 7 file = open("cspi2.dat")
#       8 lines = file.readlines()
#       9 file.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cspi2.dat'

# %%
# %matplotlib notebook
plt.plot(X_, M0_r, label="r")
plt.plot(X_, M0_g, label="g")
plt.plot(X_, M0_b, label="b")
plt.plot(X_, M0_i, label="i")
plt.legend(loc="upper right")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
plt.plot(X_, M0_g, label="0")
plt.plot(X_, M1_g, label="1")
plt.plot(X_, M2_g, label="2")
plt.legend(loc="upper right")
plt.show()

# %%
sumvec = []
for i in range(0,len(M0_i)):
    sumvec.append(1*(M0_i[i]+0*M1_i[i]+0*M2_i[i])/6000)

# %%
sumvec_0 = []
for i in range(0,len(M0_i_0)):
    sumvec_0.append(1*(M0_i_0[i]+0*M1_i_0[i]+0*M2_i_0[i]))

# %%
# %matplotlib notebook
plt.plot(X_, sumvec)
plt.plot(X_, sumvec_0)
plt.show()

# %%
M0_i[10]

# %%
X_[10]
